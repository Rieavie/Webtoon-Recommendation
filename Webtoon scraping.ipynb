# %% [markdown]
# # Import libraries

# %%
from bs4 import BeautifulSoup

# %%
import pandas as pd
import numpy as np
import itertools
import random as rd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")
import requests
import re

from time import sleep
import timeit

# %% [markdown]
# # Collecting title url

# %%
URL = "https://www.webtoons.com/en/dailySchedule"
r = requests.get(URL)
soup = BeautifulSoup(r.content, 'lxml') 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <link href="https://webtoons-static.pstatic.net/image/favicon/favicon.ico?dt=2017082301" rel="shortcut icon" type="image/x-icon"/>
#   <link href="/static/bundle/linewebtoon-f9350aec3d9f8ebe3e0e.css" rel="stylesheet" type="text/css"/>
#   <script type="text/javascript">
#    window.__headerState__ = {
# 		nclkLanguageCode: "en_en",
# 		languageCode: "en",
# 		cssCode: "en",
# 		cssCodePrefix: "",
# 		gaTrackingId: "UA-57082184-1",
# 		contentLanguage: "ENGLISH",
# 		contentLanguageCode : 'en',
# 		gakSerName: "gak.webtoons.com",
# 		gakPlatformName: "WEB_PC",
# 		serviceZone: 'GLOBAL',
# 		facebookAdId: "",
# 		nclickServer: "cc.loginfra.com",
# 		lcsServer: 'lcs.loginfra.com',
# 		browserType : "UNKNOWN",
# 		gaPageName : "",
# 		googleAdsState : {
# 			gadWebtoonReadEvent : "",
# 			title : "",
# 			titleNo : "",
# 			episodeNo : "",
# ...

# %%
all_link = soup.find_all('a', attrs={'href': re.compile("^https://")})
for link in all_link:
    # display the actual urls
    print(link.get('href'))
# Out:
# https://www.webtoons.com/en/
# https://www.webtoons.com/en/creators101/webtoon-canvas
# https://www.webtoons.com/en/dailySchedule
# https://www.webtoons.com/en/genre
# https://www.webtoons.com/en/top
# https://www.webtoons.com/en/challenge
# https://www.webtoons.com/en/romance/marry-my-husband/list?title_no=4572
# https://www.webtoons.com/en/fantasy/im-the-queen-in-this-life/list?title_no=4886
# https://www.webtoons.com/en/horror/everything-is-fine/list?title_no=2578
# https://www.webtoons.com/en/romance/blood-reverie/list?title_no=2806
# https://www.webtoons.com/en/slice-of-life/to-the-stars-and-back/list?title_no=4047
# https://www.webtoons.com/en/romance/nice-to-meet-you/list?title_no=2066
# https://www.webtoons.com/en/fantasy/the-lazy-lord-masters-the-sword/list?title_no=3349
# https://www.webtoons.com/en/slice-of-life/my-giant-nerd-boyfriend/list?title_no=958
# https://www.webtoons.com/en/action/reality-quest/list?title_no=4697
# ...

# %%
all_link = list(soup.find_all('a', attrs={'href': re.compile("^https://")}))

# %%
for link in all_link:
    # display the actual urls
    print(link.get('href'))
# Out:
# https://www.webtoons.com/en/
# https://www.webtoons.com/en/creators101/webtoon-canvas
# https://www.webtoons.com/en/dailySchedule
# https://www.webtoons.com/en/genre
# https://www.webtoons.com/en/top
# https://www.webtoons.com/en/challenge
# https://www.webtoons.com/en/romance/marry-my-husband/list?title_no=4572
# https://www.webtoons.com/en/fantasy/im-the-queen-in-this-life/list?title_no=4886
# https://www.webtoons.com/en/horror/everything-is-fine/list?title_no=2578
# https://www.webtoons.com/en/romance/blood-reverie/list?title_no=2806
# https://www.webtoons.com/en/slice-of-life/to-the-stars-and-back/list?title_no=4047
# https://www.webtoons.com/en/romance/nice-to-meet-you/list?title_no=2066
# https://www.webtoons.com/en/fantasy/the-lazy-lord-masters-the-sword/list?title_no=3349
# https://www.webtoons.com/en/slice-of-life/my-giant-nerd-boyfriend/list?title_no=958
# https://www.webtoons.com/en/action/reality-quest/list?title_no=4697
# ...

# %%
all_link_list = [link.get('href') for link in all_link]

# %%
all_link_list
# Out:
# ['https://www.webtoons.com/en/',
#  'https://www.webtoons.com/en/creators101/webtoon-canvas',
#  'https://www.webtoons.com/en/dailySchedule',
#  'https://www.webtoons.com/en/genre',
#  'https://www.webtoons.com/en/top',
#  'https://www.webtoons.com/en/challenge',
#  'https://www.webtoons.com/en/romance/marry-my-husband/list?title_no=4572',
#  'https://www.webtoons.com/en/fantasy/im-the-queen-in-this-life/list?title_no=4886',
#  'https://www.webtoons.com/en/horror/everything-is-fine/list?title_no=2578',
#  'https://www.webtoons.com/en/romance/blood-reverie/list?title_no=2806',
#  'https://www.webtoons.com/en/slice-of-life/to-the-stars-and-back/list?title_no=4047',
#  'https://www.webtoons.com/en/romance/nice-to-meet-you/list?title_no=2066',
#  'https://www.webtoons.com/en/fantasy/the-lazy-lord-masters-the-sword/list?title_no=3349',
#  'https://www.webtoons.com/en/slice-of-life/my-giant-nerd-boyfriend/list?title_no=958',
# ...

# %%
title_url = [x for x in all_link_list if 'title_no' in x]

# %%
title_url
# Out:
# ['https://www.webtoons.com/en/romance/marry-my-husband/list?title_no=4572',
#  'https://www.webtoons.com/en/fantasy/im-the-queen-in-this-life/list?title_no=4886',
#  'https://www.webtoons.com/en/horror/everything-is-fine/list?title_no=2578',
#  'https://www.webtoons.com/en/romance/blood-reverie/list?title_no=2806',
#  'https://www.webtoons.com/en/slice-of-life/to-the-stars-and-back/list?title_no=4047',
#  'https://www.webtoons.com/en/romance/nice-to-meet-you/list?title_no=2066',
#  'https://www.webtoons.com/en/fantasy/the-lazy-lord-masters-the-sword/list?title_no=3349',
#  'https://www.webtoons.com/en/slice-of-life/my-giant-nerd-boyfriend/list?title_no=958',
#  'https://www.webtoons.com/en/action/reality-quest/list?title_no=4697',
#  'https://www.webtoons.com/en/action/dungeons-and-artifacts/list?title_no=2575',
#  'https://www.webtoons.com/en/romance/to-you-who-swallowed-a-star/list?title_no=2533',
#  'https://www.webtoons.com/en/romance/the-doctors-are-out/list?title_no=1910',
# ...

# %%
len(title_url)
# Out:
# 884

# %%
title_list = soup.find_all('p', class_ = 'subj')

# %%
title_list
# Out:
# [<p class="subj">Marry My Husband</p>,
#  <p class="subj">I’m the Queen in This Life</p>,
#  <p class="subj">Everything is Fine</p>,
#  <p class="subj">Blood Reverie</p>,
#  <p class="subj">To The Stars and Back</p>,
#  <p class="subj">Nice To Meet You</p>,
#  <p class="subj">The Lazy Lord Masters the Sword</p>,
#  <p class="subj">My Giant Nerd Boyfriend</p>,
#  <p class="subj">Reality Quest</p>,
#  <p class="subj">Dungeons &amp; Artifacts</p>,
#  <p class="subj">To You Who Swallowed a Star</p>,
#  <p class="subj">The Doctors are Out</p>,
#  <p class="subj">Dear Nemesis</p>,
#  <p class="subj">Rooftops &amp; Roommates</p>,
#  <p class="subj">Scroll if You Dare</p>,
#  <p class="subj">To Tame a Fire</p>,
#  <p class="subj">Red Hood: Outlaws</p>,
#  <p class="subj">Wind Breaker</p>,
#  <p class="subj">Safely Endangered</p>,
#  <p class="subj">No Longer A Heroine!</p>,
#  <p class="subj">The Breaker: Eternal Force</p>,
#  <p class="subj">Ingrid the Plague Doctor</p>,
# ...

# %%
# dictionary of lists  
dict = {'title_url': title_url}  
       
df = pd.DataFrame(dict) 
    
# saving the dataframe 
df.to_csv('webtoon_en_title_url.csv')

# %% [markdown]
# # Collecting Webtoon info

# %%
URL = "https://www.webtoons.com/en/romance/marry-my-husband/list?title_no=4572"
r = requests.get(URL)
soup = BeautifulSoup(r.content, 'lxml')

# %%
info_details = soup.find_all('em', class_='cnt')
list_info = [x.text for x in info_details]
day_info = soup.find('p', class_ = 'day_info').text.replace('UP','')

# %%
summary = soup.find('p', class_ = 'summary').text.replace('\n','')

# %%
genre = soup.find('h2').text

# %%
author = soup.find('div', class_ = 'author_area').text.replace('author info','').replace('\n','').replace('\t','')

# %%
list_info = [x.text for x in info_details]
webtoon_en = {}
webtoon_en['title'] = soup.title.string
webtoon_en['genre'] = soup.find('h2').text
webtoon_en['author'] = soup.find('div', class_ = 'author_area').text.replace('author info','').replace('\n','').replace('\t','')
webtoon_en['day_update'] = soup.find('p', class_ = 'day_info').text.replace('UP','')
webtoon_en['view'] = list_info[0]
webtoon_en['subscribe'] = list_info[1]
webtoon_en['rate'] = list_info[2]
webtoon_en['summary'] = soup.find('p', class_ = 'summary').text.replace('\n','')

# %%
webtoon_en
# Out:
# {'title': 'Marry My Husband | WEBTOON',
#  'genre': 'Romance',
#  'author': 'sungsojak ,LICO',
#  'day_update': 'EVERY MONDAY',
#  'view': '19.2M',
#  'subscribe': '1M',
#  'rate': '9.62',
#  'summary': 'When Jiwon, a 37-year-old cancer patient, walks in on her husband and best friend, she realizes her whole life has been a lie. What’s worse, she dies a tragic death at the hands of her husband. Would things have been different if she had made different choices? Fortunately for Jiwon, she is given the chance to rewrite her fate when she is reincarnated as her younger self. This time, she vows to live a happy life. But first comes revenge. Her plan? To marry off her now former best friend to her lying, cheating husband.'}

# %%
 #if __name__ == '__main__':
        #delay = 2
    
    #print('waiting')
   # sleep(delay)

# %% [markdown]
# ## Test the code

# %%
URL = ["https://www.webtoons.com/en/romance/marry-my-husband/list?title_no=4572", "https://www.webtoons.com/en/fantasy/im-the-queen-in-this-life/list?title_no=4886"]
webtoon_en_dict = []
for url in URL:
    if __name__ == '__main__':
        # delay in seconds
        delay = 5
    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'lxml') 
    info_details = soup.find_all('em', class_='cnt')
    list_info = [x.text for x in info_details]
    webtoon_en = {}
    webtoon_en['title'] = soup.title.string
    webtoon_en['genre'] = soup.find('h2').text
    webtoon_en['author'] = soup.find('div', class_ = 'author_area').text.replace('author info','').replace('\n','').replace('\t','')
    webtoon_en['day_update'] = soup.find('p', class_ = 'day_info').text.replace('UP','')
    webtoon_en['view'] = list_info[0]
    webtoon_en['subscribe'] = list_info[1]
    webtoon_en['rate'] = list_info[2]
    webtoon_en['summary'] = soup.find('p', class_ = 'summary').text.replace('\n','')
    webtoon_en['url'] = url
    webtoon_en_dict.append(webtoon_en)
    sleep(delay)

# %%
webtoon_en_dict
# Out:
# [{'url': 'https://www.webtoons.com/en/romance/marry-my-husband/list?title_no=4572',
#   'title': 'Marry My Husband | WEBTOON',
#   'genre': 'Romance',
#   'author': 'sungsojak ,LICO',
#   'day_update': 'EVERY MONDAY',
#   'view': '19.2M',
#   'subscribe': '1M',
#   'rate': '9.63',
#   'summary': 'When Jiwon, a 37-year-old cancer patient, walks in on her husband and best friend, she realizes her whole life has been a lie. What’s worse, she dies a tragic death at the hands of her husband. Would things have been different if she had made different choices? Fortunately for Jiwon, she is given the chance to rewrite her fate when she is reincarnated as her younger self. This time, she vows to live a happy life. But first comes revenge. Her plan? To marry off her now former best friend to her lying, cheating husband.'},
#  {'url': 'https://www.webtoons.com/en/fantasy/im-the-queen-in-this-life/list?title_no=4886',
#   'title': 'I’m the Queen in This Life | WEBTOON',
#   'genre': 'Fantasy',
# ...

# %%
URL = title_url

# %%
URL
# Out:
# ['https://www.webtoons.com/en/romance/marry-my-husband/list?title_no=4572',
#  'https://www.webtoons.com/en/fantasy/im-the-queen-in-this-life/list?title_no=4886',
#  'https://www.webtoons.com/en/horror/everything-is-fine/list?title_no=2578',
#  'https://www.webtoons.com/en/romance/blood-reverie/list?title_no=2806',
#  'https://www.webtoons.com/en/slice-of-life/to-the-stars-and-back/list?title_no=4047',
#  'https://www.webtoons.com/en/romance/nice-to-meet-you/list?title_no=2066',
#  'https://www.webtoons.com/en/fantasy/the-lazy-lord-masters-the-sword/list?title_no=3349',
#  'https://www.webtoons.com/en/slice-of-life/my-giant-nerd-boyfriend/list?title_no=958',
#  'https://www.webtoons.com/en/action/reality-quest/list?title_no=4697',
#  'https://www.webtoons.com/en/action/dungeons-and-artifacts/list?title_no=2575',
#  'https://www.webtoons.com/en/romance/to-you-who-swallowed-a-star/list?title_no=2533',
#  'https://www.webtoons.com/en/romance/the-doctors-are-out/list?title_no=1910',
# ...

# %%
start = timeit.default_timer()
URL = title_url
webtoon_en_dict = []
for url in URL:
    if __name__ == '__main__':
        # delay in seconds
        delay = 2
    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'lxml') 
    info_details = soup.find_all('em', class_='cnt')
    list_info = [x.text for x in info_details]
    webtoon_en = {}
    webtoon_en['title'] = soup.title.string
    webtoon_en['genre'] = soup.find('h2').text
    webtoon_en['author'] = soup.find('div', class_ = 'author_area').text.replace('author info','').replace('\n','').replace('\t','')
    webtoon_en['day_update'] = soup.find('p', class_ = 'day_info').text.replace('UP','')
    webtoon_en['view'] = list_info[0]
    webtoon_en['subscribe'] = list_info[1]
    webtoon_en['rate'] = list_info[2]
    webtoon_en['summary'] = soup.find('p', class_ = 'summary').text.replace('\n','')
    webtoon_en['url'] = url
    webtoon_en_dict.append(webtoon_en)
    sleep(delay)

stop = timeit.default_timer()

print('Time: ', stop - start)
# Out:
# Time:  2045.8664611999993

# %%
df = pd.DataFrame.from_dict(webtoon_en_dict)

# %%
df
# Out:
#                                     title          genre  \
# 0              Marry My Husband | WEBTOON        Romance
# 1    I’m the Queen in This Life | WEBTOON        Fantasy
# 2            Everything is Fine | WEBTOON         Horror
# 3                 Blood Reverie | WEBTOON        Romance
# 4         To The Stars and Back | WEBTOON  Slice of life
# ..                                    ...            ...
# 879                     Cyko-KO | WEBTOON      Superhero
# 880                    Acursian | WEBTOON   Supernatural
# 881                Hello World! | WEBTOON  Slice of life
# 882           Penguin Loves Mev | WEBTOON  Slice of life
# 883                 Nicholalala | WEBTOON  Slice of life
#
#                                                author      day_update  \
# 0                                     sungsojak ,LICO    EVERY MONDAY
# 1                                     Themis ,Omin...    EVERY MONDAY
# ...

# %%
newdf = df.copy()

# %%
newdf[['title', 'website']] = newdf['title'].str.split('|', expand=True)

# %%
newdf
# Out:
#                            title          genre  \
# 0              Marry My Husband         Romance
# 1    I’m the Queen in This Life         Fantasy
# 2            Everything is Fine          Horror
# 3                 Blood Reverie         Romance
# 4         To The Stars and Back   Slice of life
# ..                           ...            ...
# 879                     Cyko-KO       Superhero
# 880                    Acursian    Supernatural
# 881                Hello World!   Slice of life
# 882           Penguin Loves Mev   Slice of life
# 883                 Nicholalala   Slice of life
#
#                                                author      day_update  \
# 0                                     sungsojak ,LICO    EVERY MONDAY
# 1                                     Themis ,Omin...    EVERY MONDAY
# 2                                       Mike Birchall    EVERY MONDAY
# 3                                           lifelight    EVERY MONDAY
# ...

# %%
# saving the dataframe 
newdf.to_csv('webtoon_data.csv', index = False, sep=";")
